# %% [markdown]
# # Problem 1.2
#
# This notebook is to help you get started with problem 1.2.

# %% [markdown]
# ## Setup
#
# Something like this should probably be near the top of any Jupyter notebook you create for this course.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.2(a)
#
# Here, you are to make _linear_ plots of two functions.  First, use NumPy to create an array called `x` that covers the range of interest.

# %%
x = np.arange(2,8,1)
print(x)
# Out:
# [2 3 4 5 6 7]

# %% [markdown]
# Next, use the functions `np.exp` and the operation `**` (raise to a power) to create the two function arrays.

# %%
f1 = np.exp(x)
f2 = x**3.5
print(f1, '\n\n', f2)
# Out:
# [   7.3890561    20.08553692   54.59815003  148.4131591   403.42879349
#  1096.63315843]
#
#  [ 11.3137085   46.7653718  128.         279.50849719 529.08978444
#  907.4926997 ]

# %% [markdown]
# Now use `plt.plot` to graph the two functions on the same axes.  Be sure to label the axes.  Add a title and a legend for style points.

# %%
plt.plot(x,f1,"-b",label="f1");
plt.plot(x,f2,"-r",label="f2");
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100});
plt.title('Graph of f1 & f2');
plt.legend(loc="upper left");
plt.xlabel('Domain');
plt.ylabel('Range');

# %% [markdown]
# ## 1.2(b)
#
# Here, you are to make a _semilog_ plot of the two functions.  You do not have to create any new arrays.  Python remembers what they are.  We only need to create a new plot.
#
# Use `plt.semilogy` to plot $\log y$ vs $x$.  As before, plot both functions on the same axes.  Be sure to label the axes.  Add a title and a legend for style points.

# %%
plt.semilogy(x,f1,"-b",label="f1");
plt.semilogy(x,f2,"-r",label="f2");
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100});
plt.title('Semilog Graph of f1 & f2');
plt.legend(loc="upper left");
plt.xlabel('Domain');
plt.ylabel('Range');

# %% [markdown]
# From the text of the problem, "_What outstanding feature of the exponential function jumps out in this representation?_"
#
# Use the cell below (which currently says "Type Markdown and LaTeX") to answer.  Note that, unlike the other cells in the notebook, this one is a Markdown cell.  When you run it, you will see formatted text rather than Python code and output.
#
# -----

# %% [markdown]
# The outstanding feature of the exponential function that jumps out in this representation of Semilog Graphs is that f1 = exp(x) is that is is linearly represented when put on a logarithmic scale, meaning that is has exponential growth as the domain increases from 2:7 on a semilogarithmic scale.

# %% [markdown]
# -----
#
# ## 1.2(c)
#
# Here, you are to make a _log-log_ plot of the two functions.  You do not have to create any new arrays.  Python remembers what they are.  We only need to create a new plot.
#
# Use `plt.loglog` to plot $\log y$ vs $\log x$.  As before, plot both functions on the same axes.  Be sure to label the axes.  Add a title and a legend for style points.

# %%
plt.loglog(x,f1,"-b",label="f1");
plt.loglog(x,f2,"-r",label="f2");
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100});
plt.title('Log-Log Graph of f1 & f2');
plt.legend(loc="upper left");
plt.xlabel('Domain');
plt.ylabel('Range');

# %% [markdown]
# Comment on this plot.
#
# -----

# %% [markdown]
# It is interesting to see the outcomes of the log-log Graph generated in this problem because the roles of the exponential and logarthimic functions have switched in their representations. The logarithmic function f2 is represented linearly on the log-log scale, and the exponential function is not.

# %% [markdown]
# -----
#
# ## Summary
#
# Use the space below to briefly summarize what you learned or further comment on the problem.
#
# -----

# %% [markdown]
# I have learned that when dealing with exponential and logarithmic functions, it is important to use the appropriate style of graph that is being generated to represent the outcomes of the function as it goes through its process. It will help make sense of your graphical representations, as well as clean up and simplify your physical model that you are creating so that your hypothetical presentation is more interesting and understandable.
